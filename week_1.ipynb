# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a51060Nirnaya/High_performance_computing-Hcp-/blob/main/week_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Section 1: Section A — Vector Operations & Dot Product (CPU-
# bound, loop overhead)
#
# Aim
# Measure the serial baseline performance of simple numerical
# operations (element-wise addition and dot product) implemented in
# pure Python using loops; profile to identify hotspots.
# Requirements
# • Python 3.8+
# • Standard library: time, random, cProfile, pstats, io, tracemalloc
# (No third-party libraries used.)

# %%
import random
import cProfile
import pstats
import io

def vector_add(v1, v2):
    """Element-wise addition of two vectors."""
    return [v1[i] + v2[i] for i in range(len(v1))]

def vector_dot_product(v1, v2):
    """Dot product of two vectors."""
    return sum(v1[i] * v2[i] for i in range(len(v1)))

def generate_random_vector(size):
    """Generates a vector of specified size with random floating-point numbers."""
    return [random.random() for _ in range(size)]

# Define vector size for testing
VECTOR_SIZE = 100000

v_a = generate_random_vector(VECTOR_SIZE)
v_b = generate_random_vector(VECTOR_SIZE)

# Create a cProfile instance
pr = cProfile.Profile()

print(f"Profiling vector operations with VECTOR_SIZE = {VECTOR_SIZE}")

# Profile vector addition
pr.enable()
result_add = vector_add(v_a, v_b)
pr.disable()
print(f"\nVector Addition Result (first 5 elements): {result_add[:5]}")

# Print profiling results for addition
s = io.StringIO()
sortby = 'cumulative'
ps = pstats.Stats(pr, stream=s).sort_stats(sortby)
print("\n--- Profiling Results for Vector Addition ---")
ps.print_stats()
print(s.getvalue())

# Reset profiler for dot product
pr = cProfile.Profile()

# Profile vector dot product
pr.enable()
result_dot = vector_dot_product(v_a, v_b)
pr.disable()
print(f"\nVector Dot Product Result: {result_dot}")

# Print profiling results for dot product
s = io.StringIO()
sortby = 'cumulative'
ps = pstats.Stats(pr, stream=s).sort_stats(sortby)
print("\n--- Profiling Results for Vector Dot Product ---")
ps.print_stats()
print(s.getvalue())
# Out:
# Profiling vector operations with VECTOR_SIZE = 100000
#
# Vector Addition Result (first 5 elements): [1.195743491193903, 0.958835597418123, 1.5650830827365207, 0.21484415823506053, 0.8056322139573552]
#
# --- Profiling Results for Vector Addition ---
#          233 function calls (229 primitive calls) in 0.010 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       3/2    0.000    0.000    0.009    0.004 /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py:3512(run_code)
#         1    0.000    0.000    0.006    0.006 /usr/lib/python3.12/asyncio/base_events.py:1922(_run_once)
#         2    0.000    0.000    0.003    0.002 {built-in method builtins.exec}
#         1    0.000    0.000    0.003    0.003 /tmp/ipython-input-3912600838.py:1(<cell line: 0>)
#         1    0.003    0.003    0.003    0.003 /tmp/ipython-input-3912600838.py:6(vector_add)
#         1    0.000    0.000    0.001    0.001 /usr/lib/python3.12/concurrent/futures/_base.py:537(set_result)
#         1    0.000    0.000    0.001    0.001 /usr/lib/python3.12/concurrent/futures/_base.py:337(_invoke_callbacks)
#         1    0.000    0.000    0.001    0.001 /usr/lib/python3.12/asyncio/futures.py:396(_call_set_state)
#       2/1    0.006    0.003    0.000    0.000 /usr/lib/python3.12/asyncio/events.py:86(_run)
#         1    0.000    0.000    0.000    0.000 {method 'run' of '_contextvars.Context' objects}
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/tornado/platform/asyncio.py:206(_handle_events)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/zmq/eventloop/zmqstream.py:574(_handle_events)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/zmq/eventloop/zmqstream.py:615(_handle_recv)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/zmq/eventloop/zmqstream.py:547(_run_callback)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/ipykernel/iostream.py:107(_handle_event)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.12/codeop.py:121(__call__)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/ipykernel/iostream.py:466(_schedule_in_thread)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/tornado/ioloop.py:604(call_later)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/zmq/sugar/attrsettr.py:43(__getattr__)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/zmq/eventloop/zmqstream.py:654(_rebuild_io_state)
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.12/asyncio/base_events.py:842(call_soon_threadsafe)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/tornado/platform/asyncio.py:216(call_at)
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.12/asyncio/selector_events.py:141(_write_to_self)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/zmq/sugar/socket.py:780(recv_multipart)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/zmq/sugar/attrsettr.py:66(_get_attr_opt)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py:3337(_update_code_co_name)
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.12/asyncio/base_events.py:747(call_later)
#         1    0.000    0.000    0.000    0.000 {method 'send' of '_socket.socket' objects}
#     26/24    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/tornado/queues.py:225(get)
#         3    0.000    0.000    0.000    0.000 /usr/lib/python3.12/enum.py:1561(__and__)
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.12/asyncio/base_events.py:771(call_at)
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.12/asyncio/base_events.py:818(_call_soon)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/zmq/eventloop/zmqstream.py:677(_update_handler)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#        12    0.000    0.000    0.000    0.000 /usr/lib/python3.12/enum.py:1543(_get_value)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.12/asyncio/events.py:36(__init__)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/tornado/ioloop.py:549(time)
#         3    0.000    0.000    0.000    0.000 /usr/lib/python3.12/typing.py:392(inner)
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.12/typing.py:1221(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.12/threading.py:299(__enter__)
#         4    0.000    0.000    0.000    0.000 /usr/lib/python3.12/dis.py:671(findlinestarts)
#         7    0.000    0.000    0.000    0.000 /usr/lib/python3.12/enum.py:720(__call__)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.12/contextlib.py:299(helper)
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.12/typing.py:1492(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.12/enum.py:1550(__or__)
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.12/asyncio/events.py:111(__init__)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/tornado/queues.py:256(get_nowait)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/zmq/eventloop/zmqstream.py:533(sending)
#         2    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.12/asyncio/selector_events.py:750(_process_events)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.12/contextlib.py:132(__enter__)
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.12/threading.py:424(notify_all)
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.12/queue.py:97(empty)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.12/contextlib.py:104(__init__)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/traitlets/traitlets.py:689(__get__)
#         3    0.000    0.000    0.000    0.000 /usr/lib/python3.12/asyncio/base_events.py:738(time)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.12/contextlib.py:141(__exit__)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.12/typing.py:1285(__hash__)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         7    0.000    0.000    0.000    0.000 /usr/lib/python3.12/enum.py:1128(__new__)
#         1    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.12/asyncio/base_events.py:1907(_add_callback)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/IPython/core/hooks.py:103(__call__)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         2    0.000    0.000    0.000    0.000 {method 'replace' of 'code' objects}
#         4    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/IPython/core/compilerop.py:166(extra_flags)
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.12/threading.py:394(notify)
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.12/threading.py:302(__exit__)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/traitlets/traitlets.py:651(get)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/tornado/queues.py:173(qsize)
#         3    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py:3449(compare)
#         3    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         2    0.000    0.000    0.000    0.000 {built-in method time.time}
#         2    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/IPython/utils/ipstruct.py:125(__getattr__)
#         2    0.000    0.000    0.000    0.000 {method 'co_lines' of 'code' objects}
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.12/queue.py:209(_qsize)
#         2    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py:1302(user_global_ns)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/tornado/queues.py:322(_consume_expired)
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.12/selectors.py:275(_key_from_fd)
#         2    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _heapq.heappush}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         3    0.000    0.000    0.000    0.000 /usr/lib/python3.12/asyncio/base_events.py:2017(get_debug)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/zmq/eventloop/zmqstream.py:529(receiving)
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.12/asyncio/base_events.py:543(_check_closed)
#         1    0.000    0.000    0.000    0.000 {method 'cancelled' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 {method '_is_owned' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/tornado/queues.py:59(_set_timeout)
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.12/asyncio/base_events.py:724(is_closed)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/IPython/core/hooks.py:168(pre_run_code_hook)
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.12/typing.py:2187(cast)
#
#
#
#
# Vector Dot Product Result: 25025.11748200149
#
# --- Profiling Results for Vector Dot Product ---
#          100064 function calls in 0.025 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000    0.025    0.012 /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py:3512(run_code)
#         2    0.000    0.000    0.024    0.012 {built-in method builtins.exec}
#         1    0.000    0.000    0.024    0.024 /tmp/ipython-input-3912600838.py:1(<cell line: 0>)
#         1    0.000    0.000    0.024    0.024 /tmp/ipython-input-3912600838.py:10(vector_dot_product)
#         1    0.011    0.011    0.024    0.024 {built-in method builtins.sum}
#    100001    0.013    0.000    0.013    0.000 /tmp/ipython-input-3912600838.py:12(<genexpr>)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.12/codeop.py:121(__call__)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py:3337(_update_code_co_name)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.12/contextlib.py:299(helper)
#         4    0.000    0.000    0.000    0.000 /usr/lib/python3.12/dis.py:671(findlinestarts)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.12/contextlib.py:132(__enter__)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.12/contextlib.py:104(__init__)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/traitlets/traitlets.py:689(__get__)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.12/contextlib.py:141(__exit__)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/IPython/core/hooks.py:103(__call__)
#         4    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/IPython/core/compilerop.py:166(extra_flags)
#         2    0.000    0.000    0.000    0.000 {method 'replace' of 'code' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/traitlets/traitlets.py:651(get)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/IPython/utils/ipstruct.py:125(__getattr__)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py:1302(user_global_ns)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py:3449(compare)
#         2    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'co_lines' of 'code' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.12/dist-packages/IPython/core/hooks.py:168(pre_run_code_hook)
