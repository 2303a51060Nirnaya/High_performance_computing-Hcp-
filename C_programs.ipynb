# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a51060Nirnaya/High_performance_computing-Hcp-/blob/main/C_programs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **CRITICAL**
#
# Allows only ONE thread at a time to execute a block.
#
# Used to protect shared data from race condition.

# %%
# %%writefile critical.c
# #include <stdio.h>
# #include <omp.h>
#
# int main() {
#     int total = 0;
#
#     #pragma omp parallel
#     {
#         #pragma omp critical
#         {
#             total++;
#             printf("Thread %d -> total = %d\n",
#                    omp_get_thread_num(), total);
#         }
#     }
#
#     printf("Final total = %d\n", total);
#     return 0;
# }
# Out:
# Overwriting critical.c

# %%
# !gcc critical.c -fopenmp -o critical

# %%
# !./critical
# Out:
# Thread 1 -> total = 1
# Thread 0 -> total = 2
# Final total = 2

# %% [markdown]
# **BARRIER**
#
#
# Barrier makes all threads wait until every thread reaches the same point.
#
# No thread can go ahead until all arrive

# %%
# %%writefile barrier.c
# #include <stdio.h>
# #include <omp.h>
#
# int main() {
#     #pragma omp parallel
#     {
#         int id = omp_get_thread_num();
#
#         printf("Thread %d before barrier\n", id);
#
#         #pragma omp barrier
#
#         printf("Thread %d after barrier\n", id);
#     }
#     return 0;
# }
# Out:
# Overwriting barrier.c

# %%
# !gcc barrier.c -fopenmp -o barrier

# %%
# !./barrier
# Out:
# Thread 0 before barrier
# Thread 1 before barrier
# Thread 0 after barrier
# Thread 1 after barrier

# %% [markdown]
# **ATOMIC**
#
# Similar to critical but only for single simple statement
#
# Faster than critical

# %%
# %%writefile atomic.c
# #include <stdio.h>
# #include <omp.h>
#
# int main() {
#     int sum = 0;
#
#     #pragma omp parallel
#     {
#         #pragma omp atomic
#         sum += 1;
#     }
#
#     printf("Sum = %d\n", sum);
#     return 0;
# }
# Out:
# Overwriting atomic.c

# %%
# !gcc atomic.c -fopenmp -o atomic

# %%
# !./atomic
# Out:
# Sum = 2

# %% [markdown]
# **ORDERED**
#
# Used inside parallel loops
#
# it will run according to sequencial ordered

# %%
# %%writefile ordered.c
# #include <stdio.h>
# #include <omp.h>
#
# int main() {
#
#     #pragma omp parallel for ordered
#     for(int i = 0; i < 5; i++) {
#
#         #pragma omp ordered
#         {
#             printf("Ordered Output: %d by thread %d\n",
#                    i, omp_get_thread_num());
#         }
#     }
#
#     return 0;
# }
# Out:
# Overwriting ordered.c

# %%
# !gcc ordered.c -fopenmp -o ordered

# %%
# !./ordered
# Out:
# Ordered Output: 0 by thread 0
# Ordered Output: 1 by thread 0
# Ordered Output: 2 by thread 0
# Ordered Output: 3 by thread 1
# Ordered Output: 4 by thread 1

# %% [markdown]
# openmp(lock)

# %%
# %%writefile lock_example.c
# #include <stdio.h>
# #include <omp.h>
#
# int main() {
#     int total = 0;
#     omp_lock_t lock;
#
#     // Initialize the lock
#     omp_init_lock(&lock);
#
#     #pragma omp parallel num_threads(4)
#     {
#         for(int i = 0; i < 5; i++) {
#             // Acquire lock before updating total
#             omp_set_lock(&lock);
#             total++;
#             printf("Thread %d updated total = %d\n", omp_get_thread_num(), total);
#             omp_unset_lock(&lock);  // Release lock
#         }
#     }
#
#     // Destroy the lock
#     omp_destroy_lock(&lock);
#
#     printf("Final total = %d\n", total);
#     return 0;
# }
# Out:
# Overwriting lock_example.c

# %%
# !gcc lock_example.c -fopenmp -o lock_example

# %%
# !./lock_example
# Out:
# Thread 2 updated total = 1
# Thread 2 updated total = 2
# Thread 1 updated total = 3
# Thread 1 updated total = 4
# Thread 1 updated total = 5
# Thread 3 updated total = 6
# Thread 0 updated total = 7
# Thread 1 updated total = 8
# Thread 1 updated total = 9
# Thread 3 updated total = 10
# Thread 3 updated total = 11
# Thread 2 updated total = 12
# Thread 3 updated total = 13
# Thread 2 updated total = 14
# Thread 2 updated total = 15
# Thread 3 updated total = 16
# Thread 0 updated total = 17
# Thread 0 updated total = 18
# Thread 0 updated total = 19
# Thread 0 updated total = 20
# Final total = 20

# %% [markdown]
# openmp(nolock)

# %%
# %%writefile nolock_example.c
# #include <stdio.h>
# #include <omp.h>
#
# int main() {
#     int total = 0;
#
#     #pragma omp parallel num_threads(4)
#     {
#         for(int i = 0; i < 5; i++) {
#             // No lock here
#             total++;
#             printf("Thread %d updated total = %d\n", omp_get_thread_num(), total);
#         }
#     }
#
#     printf("Final total = %d\n", total);
#     return 0;
# }
# Out:
# Overwriting nolock_example.c

# %%
# !gcc nolock_example.c -fopenmp -o nolock_example

# %%
# !./nolock_example
# Out:
# Thread 1 updated total = 2
# Thread 1 updated total = 4
# Thread 1 updated total = 5
# Thread 1 updated total = 6
# Thread 1 updated total = 7
# Thread 0 updated total = 8
# Thread 0 updated total = 9
# Thread 0 updated total = 10
# Thread 0 updated total = 11
# Thread 0 updated total = 12
# Thread 2 updated total = 3
# Thread 2 updated total = 13
# Thread 2 updated total = 14
# Thread 2 updated total = 15
# Thread 2 updated total = 16
# Thread 3 updated total = 1
# Thread 3 updated total = 17
# Thread 3 updated total = 18
# Thread 3 updated total = 19
# Thread 3 updated total = 20
# Final total = 20
